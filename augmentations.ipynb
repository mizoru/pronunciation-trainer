# %%
import torch, torchaudio
from torch import nn
from IPython.display import Audio

# %%
wav,sr  = torchaudio.load("./data/data/TEST/DR1/FJEM0/SX4.WAV.wav")

# %%
Audio(wav, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from kaggle import api

# %%
api.dataset
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_489/767817771.py in <module>
# ----> 1 api.dataset_download_files('chrisfilo/urbansound8k')
#
# ~/.conda/envs/default/lib/python3.9/site-packages/kaggle/api/kaggle_api_extended.py in dataset_download_files(self, dataset, path, force, quiet, unzip)
#    1234         outfile = os.path.join(effective_path, dataset_slug + '.zip')
#    1235         if force or self.download_needed(response, outfile, quiet):
# -> 1236             self.download_file(response, outfile, quiet)
#    1237             downloaded = True
#    1238         else:
#
# ~/.conda/envs/default/lib/python3.9/site-packages/kaggle/api/kaggle_api_extended.py in download_file(self, response, outfile, quiet, chunk_size)
#    1597                     if not data:
#    1598                         break
# -> 1599                     out.write(data)
#    1600                     size_read = min(size, size_read + chunk_size)
#    1601                     pbar.update(len(data))
#
# KeyboardInterrupt:

# %%
noize_level = torch.Tensor([10])  # [0, 40]

noize_energy = torch.norm(torch.from_numpy(noise))
audio_energy = torch.norm(wav)

alpha = (audio_energy / noize_energy) * torch.pow(10, -noize_level / 20)

# sample sub wave (but not now)
wav = wav[:noise.shape[0]]

wav_7 = wav + alpha * torch.from_numpy(noise)
wav_7.clamp_(-1, 1)
